# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = 'https://cashkaro.com'

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the content of the request with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Example: Extracting the title of the homepage
    title = soup.title.string
    print("Title of the page:", title)
    
    # Example: Extracting all links on the homepage
    links = soup.find_all('a')
    for link in links:
        print(link.get('href'))

else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Title of the page: CashKaro: Discount Coupons, Cashback Offers & Promo Codes
# /#
# /#
# /#
# /product/mobile-phones-offers
# /product/earphones-headphones-offers
# /product/laptops-offers
# /product/men-clothing
# /product/women-clothing
# /product/men-shoes
# /product/women-shoes
# /product/beauty
# /product/grocery
# /product/baby-products
# /#
# /stores
# /brands
# /product
# /
# /help
# https://cashkaro.com/refer-and-earn
# https://cashkaro.com/stores/amazon
# https://cashkaro.com/stores/flipkart
# https://cashkaro.com/stores/myntra
# https://cashkaro.com/stores/ajio-coupons
# https://cashkaro.com/stores/tatacliq-coupons
# https://cashkaro.com/shop/amazon-sale-offers
# https://cashkaro.com/shop/amazon-sale-offers
# https://cashkaro.com/stores/buykaro
# https://cashkaro.com/stores/buykaro
# https://cashkaro.com/shop/tatacliq-sale
# https://cashkaro.com/shop/tatacliq-sale
# None
# https://cashkaro.com/stores/amazon
# https://cashkaro.com/stores/flipkart
# https://cashkaro.com/stores/tatacliq-coupons
# https://cashkaro.com/stores/snapdeal
# https://cashkaro.com/stores/itc-estore-offers
# https://cashkaro.com/stores/myntra
# https://cashkaro.com/stores/ajio-coupons
# https://cashkaro.com/stores/nykaafashion-coupons
# https://cashkaro.com/stores/puma-coupons
# https://cashkaro.com/stores/adidas
# https://cashkaro.com/stores/urbanic-coupon-codes
# https://cashkaro.com/stores/nykaa
# https://cashkaro.com/stores/mama-earth-coupons
# https://cashkaro.com/stores/buywow-coupons
# https://cashkaro.com/stores/mcaffeine-coupons
# https://cashkaro.com/stores/minimalist-coupons
# https://cashkaro.com/stores/thedermaco-coupons
# https://cashkaro.com/stores/croma
# https://cashkaro.com/stores/oneplus-coupons
# https://cashkaro.com/stores/dell
# https://cashkaro.com/stores/samsung-offers
# https://cashkaro.com/stores/apple-offers
# https://cashkaro.com/stores/lenovo
# https://cashkaro.com/stores/boat-coupon
# https://cashkaro.com/stores/1mg-coupons
# https://cashkaro.com/stores/netmeds-coupons
# https://cashkaro.com/stores/truemeds-coupon-code
# https://cashkaro.com/stores/healthkart
# https://cashkaro.com/stores/booking
# https://cashkaro.com/stores/cleartrip
# https://cashkaro.com/stores/makemytrip-domesticflights
# https://cashkaro.com/stores/ixigo-coupons
# https://cashkaro.com/stores/clovia-coupons
# https://cashkaro.com/stores/zivame
# https://cashkaro.com/stores/xyxx-discount-code
# https://cashkaro.com/stores/shyaway-coupons
# https://cashkaro.com/stores/damensch-coupon-codes
# https://cashkaro.com/stores/go-daddy
# https://cashkaro.com/stores/bigrock
# https://cashkaro.com/stores/udemy-coupons
# https://cashkaro.com/stores/pepperfry
# https://cashkaro.com/stores/firstcry
# None
# https://cashkaro.com/product/lingerie
# https://cashkaro.com/product/home-appliances
# https://cashkaro.com/product/kitchen-appliances
# https://cashkaro.com/product/home-appliances/washing-machines-offers
# https://cashkaro.com/product/home-appliances/refrigerators-offers
# https://cashkaro.com/product/baby-products/baby-bath-products
# https://cashkaro.com/product/beauty/fragrances
# https://cashkaro.com/product/beauty/skin-care-products
# https://cashkaro.com/product/beauty/hair-care-products
# https://cashkaro.com/product/beauty/beard-shaving
# https://cashkaro.com/product/home-appliances/air-conditioners-offers
# https://cashkaro.com/product/baby-products/baby-skin-care
# https://cashkaro.com/product/home-appliances/air-purifiers
# https://cashkaro.com/product/electronics-products
# https://cashkaro.com/product/fashion-accessories
# https://cashkaro.com/product/personal-care-appliances
# /page/why-cashkaro
# /press
# /blog/
# /testimonials
# /terms-conditions
# /privacy-policy
# /anti-spam-policy
# /refer-and-earn
# /page/careers
# /page/become-our-partner
# /page/student-program
# /help
# /contact-us?topic=other-questions
# https://www.facebook.com/cashkaro?utm_source=footer&utm_medium=facebook&utm_campaign=footer-links
# https://twitter.com/cashkarocom?utm_source=footer&utm_medium=twitter&utm_campaign=footer-links
# https://www.instagram.com/cashkaro?utm_source=footer&utm_medium=instagram&utm_campaign=footer-links
# https://www.linkedin.com/company/cashkaro-com?utm_source=footer&utm_medium=linkedin&utm_campaign=footer-links
# https://www.youtube.com/c/cashkaroindia?utm_source=footer&utm_medium=youtube&utm_campaign=footer-links
# https://pouringpounds.com
# https://play.google.com/store/apps/details?id=com.cashkaro&referrer=r%3D32%26refname%3DCashKaro%26utm_source%3Ddesktop_footer
# https://cashkaro.onelink.me/TQWE?pid=AppReferral&c=FooterLink&r=32&refName=CashKaro&af_referrer_customer_id=32&af_referrer_name=CashKaro&is_retargeting=true
# https://cashk.app.link/tZMpLg3eYob

# %%
# prompt: how to save scaped data as a csv file

import csv

# Create a CSV file
with open('scraped_data.csv', 'w', newline='') as csvfile:
    # Create a CSV writer object
    writer = csv.writer(csvfile)

    # Write the header row
    writer.writerow(['Title', 'Link'])

    # Write the data rows
    for link in links:
        writer.writerow([link.get_text(), link.get('href')])
